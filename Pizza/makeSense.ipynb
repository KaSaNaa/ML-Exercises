# %%
import numpy as np # type: ignore
import matplotlib.pyplot as plt # type: ignore
import seaborn as sea # type: ignore

# %%
sea.set()
plt.axis([0, 50, 0, 50])                                 # scale axes (0 to 50)
plt.xticks(fontsize=10)                                  # set x axis ticks
plt.yticks(fontsize=10)                                  # set y axis ticks
plt.xlabel("Reservations", fontsize=10)                  # set x axis label
plt.ylabel("Pizzas", fontsize=10)                        # set y axis label
X, Y = np.loadtxt("pizza.txt", skiprows=1, unpack=True)  # load data
plt.plot(X, Y, "bo")                                     # plot data
plt.show()

# %%
def predict(X, w):
    return X * w

# %%
predict(23, 2.1)
# Out:
# 48.300000000000004

# %%
w = 2.1
error = predict(X, w) - Y
